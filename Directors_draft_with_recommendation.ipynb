# %% [markdown]
# # What Would I Tell the CEO of Microsoft About Getting Into The Film Industry?
# In this project, we (Michael, Teigen, Ely and Louis,) are making recommendations as if Microsoft wanted to enter
# the film industry. We will look through our available data, merge data from different pre-existing sources, and
# pitch our reccomendations using our data to back up our logic.

# %%
#first we must import the libraries that we want to use
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
movie_budgets_df = pd.read_csv('tn.movie_budgets.csv.gz')   #Michael has expertise on this
                                                                       #dataframe from The Numbers
movie_studios = pd.read_csv('bom.movie_gross.csv.gz')       #Teigen's has expertise on 
                                                                       #this dataframe from Box Office Mojo
title_basics = pd.read_csv('imdb.title.basics.csv.gz')      #Louis' has expertise on this 
                                                                       #dataframe from IMDB
title_ratings = pd.read_csv('imdb.title.ratings.csv.gz')    #as well as this one 
title_principal=pd.read_csv('imdb.title.principals.csv.gz') #as well as this one
name_basics=pd.read_csv('imdb.name.basics.csv.gz')          #as well as this one
tmdb = pd.read_csv('tmdb.movies.csv.gz')                    #Ely has expertise on this dataframe
                                                                       #from The Movie Database

# %% [markdown]
# # Now that we have loaded all of our raw data, let's merge it together!

# %%
#firstly, the tmbd database has it's genre's encoded so we must decode the genre's using the below dictionary
genres={'28':"Action",
'12':"Adventure",
'16':"Animation",
'35':"Comedy",
'80':"Crime",
'99':"Documentary",
'18':"Drama",
'10751':"Family",
'14':"Fantasy",
'36':"History",
'27':"Horror",
'10402':"Music",
'9648':"Mystery",
'10749':"Romance",
'878':"Science Fiction",
'10770':"TV Movie",
'53':"Thriller",
'10752':"War",
'37':"Western"}

tmdb = tmdb.replace(pd.Series(genres).astype(str), regex=True)
tmdb['genre_ids']=tmdb['genre_ids'].str.strip('[]').str.split(', ')

# %%
tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
tmdb.head()
# Out:
#    Unnamed: 0                                genre_ids     id  \
# 0           0             [Adventure, Fantasy, Family]  12444
# 1           1  [Fantasy, Adventure, Animation, Family]  10191
# 2           2     [Adventure, Action, Science Fiction]  10138
# 3           3              [Animation, Comedy, Family]    862
# 4           4     [Action, Science Fiction, Adventure]  27205
#
#   original_language                                original_title  popularity  \
# 0                en  Harry Potter and the Deathly Hallows: Part 1      33.533
# 1                en                      How to Train Your Dragon      28.734
# 2                en                                    Iron Man 2      28.515
# 3                en                                     Toy Story      28.005
# 4                en                                     Inception      27.920
#
#           release_date                                         title  \
# 0           2010-11-19  Harry Potter and the Deathly Hallows: Part 1
# 1           2010-03-26                      How to Train Your Dragon
# 2           2010-05-07                                    Iron Man 2
# 3  1Documentary5-11-22                                     Toy Story
# 4    2010-07-Animation                                     Inception
#
#    vote_average  vote_count
# 0           7.7       10788
# 1           7.7        7610
# 2           6.8       12368
# 3           7.9       10174
# 4           8.3       22186

# %%
#secondly, we must merge the IMDB title basics and title ratings
title_master = title_basics.merge(title_ratings, how='inner')

# %%
title_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73856 entries, 0 to 73855
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           73856 non-null  object
#  1   primary_title    73856 non-null  object
#  2   original_title   73856 non-null  object
#  3   start_year       73856 non-null  int64
#  4   runtime_minutes  66236 non-null  float64
#  5   genres           73052 non-null  object
#  6   averagerating    73856 non-null  float64
#  7   numvotes         73856 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 5.1+ MB

# %%
title_master.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
#thirdly, we must merge the tmdb database with the imdb database. we chose to do an inner merge, here because we 
#are only interested in the movies that these dataframes have in common
tmdb_and_imdb = tmdb.merge(title_master, how = 'inner')

# %%
tmdb_and_imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17805 entries, 0 to 17804
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         17805 non-null  int64
#  1   genre_ids          17805 non-null  object
#  2   id                 17805 non-null  int64
#  3   original_language  17805 non-null  object
#  4   original_title     17805 non-null  object
#  5   popularity         17805 non-null  float64
#  6   release_date       17805 non-null  object
#  7   title              17805 non-null  object
#  8   vote_average       17805 non-null  float64
#  9   vote_count         17805 non-null  int64
#  10  tconst             17805 non-null  object
#  11  primary_title      17805 non-null  object
#  12  start_year         17805 non-null  int64
#  13  runtime_minutes    17308 non-null  float64
#  14  genres             17745 non-null  object
#  15  averagerating      17805 non-null  float64
#  16  numvotes           17805 non-null  int64
# dtypes: float64(4), int64(5), object(8)
# memory usage: 2.4+ MB

# %%
tmdb_and_imdb.head()
# Out:
#    Unnamed: 0                                genre_ids     id  \
# 0           0             [Adventure, Fantasy, Family]  12444
# 1           1  [Fantasy, Adventure, Animation, Family]  10191
# 2           2     [Adventure, Action, Science Fiction]  10138
# 3           4     [Action, Science Fiction, Adventure]  27205
# 4           5             [Adventure, Fantasy, Family]  32657
#
#   original_language                                     original_title  \
# 0                en       Harry Potter and the Deathly Hallows: Part 1
# 1                en                           How to Train Your Dragon
# 2                en                                         Iron Man 2
# 3                en                                          Inception
# 4                en  Percy Jackson & the Olympians: The Lightning T...
#
#    popularity       release_date  \
# 0      33.533         2010-11-19
# 1      28.734         2010-03-26
# 2      28.515         2010-05-07
# 3      27.920  2010-07-Animation
# 4      26.691         2010-02-11
#
#                                                title  vote_average  \
# 0       Harry Potter and the Deathly Hallows: Part 1           7.7
# 1                           How to Train Your Dragon           7.7
# 2                                         Iron Man 2           6.8
# 3                                          Inception           8.3
# 4  Percy Jackson & the Olympians: The Lightning T...           6.1
#
#    vote_count     tconst                                      primary_title  \
# 0       10788  tt0926084       Harry Potter and the Deathly Hallows: Part 1
# 1        7610  tt0892769                           How to Train Your Dragon
# 2       12368  tt1228705                                         Iron Man 2
# 3       22186  tt1375666                                          Inception
# 4        4229  tt0814255  Percy Jackson & the Olympians: The Lightning T...
#
#    start_year  runtime_minutes                      genres  averagerating  \
# 0        2010            146.0   Adventure,Fantasy,Mystery            7.7
# 1        2010             98.0  Action,Adventure,Animation            8.1
# 2        2010            124.0     Action,Adventure,Sci-Fi            7.0
# 3        2010            148.0     Action,Adventure,Sci-Fi            8.8
# 4        2010            118.0    Adventure,Family,Fantasy            5.9
#
#    numvotes
# 0    425530
# 1    611299
# 2    657690
# 3   1841066
# 4    165108

# %%
#the next dataframe we want to fold in has the column "movie" but we want to rename it to title so the merge can 
#happen on the title of the film, so we must rename the column
movie_budgets_df = movie_budgets_df.rename(columns={'movie':'title'})

# %%
#now we want to merge the financial dataframe from The Numbers with all the others based on title, so we specify that 
#with the on = 'title'
master_unclean = tmdb_and_imdb.merge(movie_budgets_df, on = 'title', how = 'inner')

# %%
#let's take a look at the amount of information we have now and the types of information in our columns
#we can see where we have duplicate columns, we now have x and y versions to distinguish them from each other
#runtime_minutes and genres are the only two columns that has missing value
master_unclean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2955 entries, 0 to 2954
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2955 non-null   int64
#  1   genre_ids          2955 non-null   object
#  2   id_x               2955 non-null   int64
#  3   original_language  2955 non-null   object
#  4   original_title     2955 non-null   object
#  5   popularity         2955 non-null   float64
#  6   release_date_x     2955 non-null   object
#  7   title              2955 non-null   object
#  8   vote_average       2955 non-null   float64
#  9   vote_count         2955 non-null   int64
#  10  tconst             2955 non-null   object
#  11  primary_title      2955 non-null   object
#  12  start_year         2955 non-null   int64
#  13  runtime_minutes    2860 non-null   float64
#  14  genres             2948 non-null   object
#  15  averagerating      2955 non-null   float64
#  16  numvotes           2955 non-null   int64
#  17  id_y               2955 non-null   int64
#  18  release_date_y     2955 non-null   object
#  19  production_budget  2955 non-null   object
#  20  domestic_gross     2955 non-null   object
#  21  worldwide_gross    2955 non-null   object
# dtypes: float64(4), int64(6), object(12)
# memory usage: 531.0+ KB

# %%
#now we want to exclude movies from this master dataframe which are less than half an hour and more than three 
#hours, because we want to base our recommendations on films that are typically seen in the movie theater, no 
#short film stand alones, and no art-film style epics, and put that information on a new dataframe called run_time
filtered_run_time = master_unclean.loc[(master_unclean['runtime_minutes'] > 30) & (master_unclean['runtime_minutes'] < 180)]
filtered_run_time
# Out:
#       Unnamed: 0                                genre_ids    id_x  \
# 0              1  [Fantasy, Adventure, Animation, Family]   10191
# 1              2     [Adventure, Action, Science Fiction]   10138
# 2              4     [Action, Science Fiction, Adventure]   27205
# 3              5             [Adventure, Fantasy, Family]   32657
# 4              7              [Animation, Family, Comedy]   10193
# ...          ...                                      ...     ...
# 2950       25825                [Action, Science Fiction]  448764
# 2951       26040                                       []  509314
# 2952       26211                               [Thriller]  565736
# 2953       26323                                       []  509316
# 2954       26425                                  [Music]  509306
#
#      original_language                                     original_title  \
# 0                   en                           How to Train Your Dragon
# 1                   en                                         Iron Man 2
# 2                   en                                          Inception
# 3                   en  Percy Jackson & the Olympians: The Lightning T...
# 4                   en                                        Toy Story 3
# ...                ...                                                ...
# 2950                en                                              Molly
# 2951                en                                            The Box
# 2952                en                                            The Box
# 2953                en                                            The Box
# 2954                en                                            The Box
#
#       popularity     release_date_x  \
# 0         28.734         2010-03-26
# 1         28.515         2010-05-07
# 2         27.920  2010-07-Animation
# 3         26.691         2010-02-11
# 4         24.445         2010-06-17
# ...          ...                ...
# 2950       1.400      20Drama-09-25
# 2951       0.840      20Drama-03-04
# 2952       0.600      20Drama-05-21
# 2953       0.600      20Drama-03-04
# 2954       0.600      20Drama-03-04
#
#                                                   title  vote_average  \
# 0                              How to Train Your Dragon           7.7
# 1                                            Iron Man 2           6.8
# 2                                             Inception           8.3
# 3     Percy Jackson & the Olympians: The Lightning T...           6.1
# 4                                           Toy Story 3           7.7
# ...                                                 ...           ...
# 2950                                              Molly           5.8
# 2951                                            The Box           8.0
# 2952                                            The Box          10.0
# 2953                                            The Box           8.0
# 2954                                            The Box           6.0
#
#       vote_count  ... start_year runtime_minutes                      genres  \
# 0           7610  ...       2010            98.0  Action,Adventure,Animation
# 1          12368  ...       2010           124.0     Action,Adventure,Sci-Fi
# 2          22186  ...       2010           148.0     Action,Adventure,Sci-Fi
# 3           4229  ...       2010           118.0    Adventure,Family,Fantasy
# 4           8340  ...       2010           103.0  Adventure,Animation,Comedy
# ...          ...  ...        ...             ...                         ...
# 2950           5  ...       2017            91.0               Action,Sci-Fi
# 2951           1  ...       2011            89.0                       Drama
# 2952           1  ...       2011            89.0                       Drama
# 2953           1  ...       2011            89.0                       Drama
# 2954           1  ...       2011            89.0                       Drama
#
#       averagerating numvotes  id_y  release_date_y  production_budget  \
# 0               8.1   611299    30    Mar 26, 2010       $165,000,000
# 1               7.0   657690    15     May 7, 2010       $170,000,000
# 2               8.8  1841066    38    Jul 16, 2010       $160,000,000
# 3               5.9   165108    17    Feb 12, 2010        $95,000,000
# 4               8.3   682218    47    Jun 18, 2010       $200,000,000
# ...             ...      ...   ...             ...                ...
# 2950            4.6      726    81    Oct 22, 1999        $21,000,000
# 2951            6.3       51    66     Nov 6, 2009        $25,000,000
# 2952            6.3       51    66     Nov 6, 2009        $25,000,000
# 2953            6.3       51    66     Nov 6, 2009        $25,000,000
# 2954            6.3       51    66     Nov 6, 2009        $25,000,000
#
#      domestic_gross worldwide_gross
# 0      $217,581,232    $494,870,992
# 1      $312,433,331    $621,156,389
# 2      $292,576,195    $835,524,642
# 3       $88,768,303    $223,050,874
# 4      $415,004,880  $1,068,879,522
# ...             ...             ...
# 2950        $17,396         $17,396
# 2951    $15,051,977     $34,356,760
# 2952    $15,051,977     $34,356,760
# 2953    $15,051,977     $34,356,760
# 2954    $15,051,977     $34,356,760
#
# [2857 rows x 22 columns]

# %%
#let's take a look at the column names that are redundant
filtered_run_time.columns
# Out:
# Index(['Unnamed: 0', 'genre_ids', 'id_x', 'original_language',
#        'original_title', 'popularity', 'release_date_x', 'title',
#        'vote_average', 'vote_count', 'tconst', 'primary_title', 'start_year',
#        'runtime_minutes', 'genres', 'averagerating', 'numvotes', 'id_y',
#        'release_date_y', 'production_budget', 'domestic_gross',
#        'worldwide_gross'],
#       dtype='object')

# %%
#here, we want to drop some columns where the information is irrelivant or duplicated 
filtered_less_columns = filtered_run_time.drop(['Unnamed: 0', 'id_x', 'original_title', 'tconst', 'start_year', 'id_y',\
                                    'genres', 'release_date_x', 'primary_title', 'original_language'], axis = 1)

# %%
#let's take a look at where our dataframe is right now
filtered_less_columns
# Out:
#                                     genre_ids  popularity  \
# 0     [Fantasy, Adventure, Animation, Family]      28.734
# 1        [Adventure, Action, Science Fiction]      28.515
# 2        [Action, Science Fiction, Adventure]      27.920
# 3                [Adventure, Fantasy, Family]      26.691
# 4                 [Animation, Family, Comedy]      24.445
# ...                                       ...         ...
# 2950                [Action, Science Fiction]       1.400
# 2951                                       []       0.840
# 2952                               [Thriller]       0.600
# 2953                                       []       0.600
# 2954                                  [Music]       0.600
#
#                                                   title  vote_average  \
# 0                              How to Train Your Dragon           7.7
# 1                                            Iron Man 2           6.8
# 2                                             Inception           8.3
# 3     Percy Jackson & the Olympians: The Lightning T...           6.1
# 4                                           Toy Story 3           7.7
# ...                                                 ...           ...
# 2950                                              Molly           5.8
# 2951                                            The Box           8.0
# 2952                                            The Box          10.0
# 2953                                            The Box           8.0
# 2954                                            The Box           6.0
#
#       vote_count  runtime_minutes  averagerating  numvotes release_date_y  \
# 0           7610             98.0            8.1    611299   Mar 26, 2010
# 1          12368            124.0            7.0    657690    May 7, 2010
# 2          22186            148.0            8.8   1841066   Jul 16, 2010
# 3           4229            118.0            5.9    165108   Feb 12, 2010
# 4           8340            103.0            8.3    682218   Jun 18, 2010
# ...          ...              ...            ...       ...            ...
# 2950           5             91.0            4.6       726   Oct 22, 1999
# 2951           1             89.0            6.3        51    Nov 6, 2009
# 2952           1             89.0            6.3        51    Nov 6, 2009
# 2953           1             89.0            6.3        51    Nov 6, 2009
# 2954           1             89.0            6.3        51    Nov 6, 2009
#
#      production_budget domestic_gross worldwide_gross
# 0         $165,000,000   $217,581,232    $494,870,992
# 1         $170,000,000   $312,433,331    $621,156,389
# 2         $160,000,000   $292,576,195    $835,524,642
# 3          $95,000,000    $88,768,303    $223,050,874
# 4         $200,000,000   $415,004,880  $1,068,879,522
# ...                ...            ...             ...
# 2950       $21,000,000        $17,396         $17,396
# 2951       $25,000,000    $15,051,977     $34,356,760
# 2952       $25,000,000    $15,051,977     $34,356,760
# 2953       $25,000,000    $15,051,977     $34,356,760
# 2954       $25,000,000    $15,051,977     $34,356,760
#
# [2857 rows x 12 columns]

# %%
#add a "year" column and a 'month' column to our dataframe 
import datetime

# %%
filtered_less_columns['year']=pd.to_datetime(filtered_less_columns['release_date_y']).dt.year

# %%
filtered_less_columns['month']=pd.to_datetime(filtered_less_columns['release_date_y']).dt.month

# %%
filtered_less_columns
# Out:
#                                     genre_ids  popularity  \
# 0     [Fantasy, Adventure, Animation, Family]      28.734
# 1        [Adventure, Action, Science Fiction]      28.515
# 2        [Action, Science Fiction, Adventure]      27.920
# 3                [Adventure, Fantasy, Family]      26.691
# 4                 [Animation, Family, Comedy]      24.445
# ...                                       ...         ...
# 2950                [Action, Science Fiction]       1.400
# 2951                                       []       0.840
# 2952                               [Thriller]       0.600
# 2953                                       []       0.600
# 2954                                  [Music]       0.600
#
#                                                   title  vote_average  \
# 0                              How to Train Your Dragon           7.7
# 1                                            Iron Man 2           6.8
# 2                                             Inception           8.3
# 3     Percy Jackson & the Olympians: The Lightning T...           6.1
# 4                                           Toy Story 3           7.7
# ...                                                 ...           ...
# 2950                                              Molly           5.8
# 2951                                            The Box           8.0
# 2952                                            The Box          10.0
# 2953                                            The Box           8.0
# 2954                                            The Box           6.0
#
#       vote_count  runtime_minutes  averagerating  numvotes release_date_y  \
# 0           7610             98.0            8.1    611299   Mar 26, 2010
# 1          12368            124.0            7.0    657690    May 7, 2010
# 2          22186            148.0            8.8   1841066   Jul 16, 2010
# 3           4229            118.0            5.9    165108   Feb 12, 2010
# 4           8340            103.0            8.3    682218   Jun 18, 2010
# ...          ...              ...            ...       ...            ...
# 2950           5             91.0            4.6       726   Oct 22, 1999
# 2951           1             89.0            6.3        51    Nov 6, 2009
# 2952           1             89.0            6.3        51    Nov 6, 2009
# 2953           1             89.0            6.3        51    Nov 6, 2009
# 2954           1             89.0            6.3        51    Nov 6, 2009
#
#      production_budget domestic_gross worldwide_gross  year  month
# 0         $165,000,000   $217,581,232    $494,870,992  2010      3
# 1         $170,000,000   $312,433,331    $621,156,389  2010      5
# 2         $160,000,000   $292,576,195    $835,524,642  2010      7
# 3          $95,000,000    $88,768,303    $223,050,874  2010      2
# 4         $200,000,000   $415,004,880  $1,068,879,522  2010      6
# ...                ...            ...             ...   ...    ...
# 2950       $21,000,000        $17,396         $17,396  1999     10
# 2951       $25,000,000    $15,051,977     $34,356,760  2009     11
# 2952       $25,000,000    $15,051,977     $34,356,760  2009     11
# 2953       $25,000,000    $15,051,977     $34,356,760  2009     11
# 2954       $25,000,000    $15,051,977     $34,356,760  2009     11
#
# [2857 rows x 14 columns]

# %%
#because we want our recommendations to be relevent to the current market, we only want to look at movies from the 
#last few years, so let's filter those out
filtered_year=filtered_less_columns.loc[filtered_less_columns['year'] >= 2010]

# %%
#let's take a look at what we have at this point
filtered_year
# Out:
#                                     genre_ids  popularity  \
# 0     [Fantasy, Adventure, Animation, Family]      28.734
# 1        [Adventure, Action, Science Fiction]      28.515
# 2        [Action, Science Fiction, Adventure]      27.920
# 3                [Adventure, Fantasy, Family]      26.691
# 4                 [Animation, Family, Comedy]      24.445
# ...                                       ...         ...
# 2943           [Action, Adventure, Animation]       2.707
# 2946              [Horror, Mystery, Thriller]       1.816
# 2947              [Horror, Mystery, Thriller]       1.816
# 2948              [Horror, Mystery, Thriller]       1.816
# 2949              [Horror, Mystery, Thriller]       1.816
#
#                                                   title  vote_average  \
# 0                              How to Train Your Dragon           7.7
# 1                                            Iron Man 2           6.8
# 2                                             Inception           8.3
# 3     Percy Jackson & the Olympians: The Lightning T...           6.1
# 4                                           Toy Story 3           7.7
# ...                                                 ...           ...
# 2943                         Bilal: A New Breed of Hero           6.8
# 2946                                                  3           6.0
# 2947                                                  3           6.0
# 2948                                                  3           6.0
# 2949                                                  3           6.0
#
#       vote_count  runtime_minutes  averagerating  numvotes release_date_y  \
# 0           7610             98.0            8.1    611299   Mar 26, 2010
# 1          12368            124.0            7.0    657690    May 7, 2010
# 2          22186            148.0            8.8   1841066   Jul 16, 2010
# 3           4229            118.0            5.9    165108   Feb 12, 2010
# 4           8340            103.0            8.3    682218   Jun 18, 2010
# ...          ...              ...            ...       ...            ...
# 2943          54            105.0            8.0     16854    Feb 2, 2018
# 2946           2            119.0            6.7      4722   Sep 16, 2011
# 2947           2            145.0            7.2      3471   Sep 16, 2011
# 2948           2            115.0            6.1       101   Sep 16, 2011
# 2949           2             80.0            3.9       166   Sep 16, 2011
#
#      production_budget domestic_gross worldwide_gross  year  month
# 0         $165,000,000   $217,581,232    $494,870,992  2010      3
# 1         $170,000,000   $312,433,331    $621,156,389  2010      5
# 2         $160,000,000   $292,576,195    $835,524,642  2010      7
# 3          $95,000,000    $88,768,303    $223,050,874  2010      2
# 4         $200,000,000   $415,004,880  $1,068,879,522  2010      6
# ...                ...            ...             ...   ...    ...
# 2943       $30,000,000       $490,973        $648,599  2018      2
# 2946        $7,200,000        $59,774        $295,492  2011      9
# 2947        $7,200,000        $59,774        $295,492  2011      9
# 2948        $7,200,000        $59,774        $295,492  2011      9
# 2949        $7,200,000        $59,774        $295,492  2011      9
#
# [2413 rows x 14 columns]

# %%
#now we must clean up this financial information by removing punctuation and making sure that these numbers are 
#integers and therefore we will be able to perform mathmatical manipulation on them in the future 
filtered_year['production_budget'] = filtered_year['production_budget'].str.replace(',', '')
filtered_year['production_budget'] = filtered_year['production_budget'].str.replace('$', '')
filtered_year['production_budget'] = filtered_year['production_budget'].astype(int)
filtered_year['domestic_gross'] = filtered_year['domestic_gross'].str.replace(',', '').str.replace('$', '')
filtered_year['domestic_gross'] = filtered_year['domestic_gross'].astype(int)
filtered_year['worldwide_gross'] = filtered_year['worldwide_gross'].str.replace(',', '').str.replace('$', '')
filtered_year['worldwide_gross'] = filtered_year['worldwide_gross'].astype(int)
filtered_year['total_gross'] = filtered_year['domestic_gross'] + filtered_year['worldwide_gross']
filtered_year['ROI'] = (filtered_year['total_gross'] / filtered_year['production_budget']) * 100
# Out:
# <ipython-input-25-f99886e2eb9c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_year['production_budget'] = filtered_year['production_budget'].str.replace(',', '')
# <ipython-input-25-f99886e2eb9c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_year['production_budget'] = filtered_year['production_budget'].str.replace('$', '')
# <ipython-input-25-f99886e2eb9c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_year['production_budget'] = filtered_year['production_budget'].astype(int)
# <ipython-input-25-f99886e2eb9c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_year['domestic_gross'] = filtered_year['domestic_gross'].str.replace(',', '').str.replace('$', '')
# <ipython-input-25-f99886e2eb9c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_year['domestic_gross'] = filtered_year['domestic_gross'].astype(int)
# <ipython-input-25-f99886e2eb9c>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_year['worldwide_gross'] = filtered_year['worldwide_gross'].str.replace(',', '').str.replace('$', '')
# <ipython-input-25-f99886e2eb9c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_year['worldwide_gross'] = filtered_year['worldwide_gross'].astype(int)
# <ipython-input-25-f99886e2eb9c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_year['total_gross'] = filtered_year['domestic_gross'] + filtered_year['worldwide_gross']
# <ipython-input-25-f99886e2eb9c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_year['ROI'] = (filtered_year['total_gross'] / filtered_year['production_budget']) * 100

# %%
#now let's make a Return on Investment column, using the fincial data we just cleaned
filtered_year['ROI'] = (filtered_year['total_gross'] / filtered_year['production_budget']) * 100
# Out:
# <ipython-input-26-521bb0bafb84>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_year['ROI'] = (filtered_year['total_gross'] / filtered_year['production_budget']) * 100

# %%
filtered_year
# Out:
#                                     genre_ids  popularity  \
# 0     [Fantasy, Adventure, Animation, Family]      28.734
# 1        [Adventure, Action, Science Fiction]      28.515
# 2        [Action, Science Fiction, Adventure]      27.920
# 3                [Adventure, Fantasy, Family]      26.691
# 4                 [Animation, Family, Comedy]      24.445
# ...                                       ...         ...
# 2943           [Action, Adventure, Animation]       2.707
# 2946              [Horror, Mystery, Thriller]       1.816
# 2947              [Horror, Mystery, Thriller]       1.816
# 2948              [Horror, Mystery, Thriller]       1.816
# 2949              [Horror, Mystery, Thriller]       1.816
#
#                                                   title  vote_average  \
# 0                              How to Train Your Dragon           7.7
# 1                                            Iron Man 2           6.8
# 2                                             Inception           8.3
# 3     Percy Jackson & the Olympians: The Lightning T...           6.1
# 4                                           Toy Story 3           7.7
# ...                                                 ...           ...
# 2943                         Bilal: A New Breed of Hero           6.8
# 2946                                                  3           6.0
# 2947                                                  3           6.0
# 2948                                                  3           6.0
# 2949                                                  3           6.0
#
#       vote_count  runtime_minutes  averagerating  numvotes release_date_y  \
# 0           7610             98.0            8.1    611299   Mar 26, 2010
# 1          12368            124.0            7.0    657690    May 7, 2010
# 2          22186            148.0            8.8   1841066   Jul 16, 2010
# 3           4229            118.0            5.9    165108   Feb 12, 2010
# 4           8340            103.0            8.3    682218   Jun 18, 2010
# ...          ...              ...            ...       ...            ...
# 2943          54            105.0            8.0     16854    Feb 2, 2018
# 2946           2            119.0            6.7      4722   Sep 16, 2011
# 2947           2            145.0            7.2      3471   Sep 16, 2011
# 2948           2            115.0            6.1       101   Sep 16, 2011
# 2949           2             80.0            3.9       166   Sep 16, 2011
#
#       production_budget  domestic_gross  worldwide_gross  year  month  \
# 0             165000000       217581232        494870992  2010      3
# 1             170000000       312433331        621156389  2010      5
# 2             160000000       292576195        835524642  2010      7
# 3              95000000        88768303        223050874  2010      2
# 4             200000000       415004880       1068879522  2010      6
# ...                 ...             ...              ...   ...    ...
# 2943           30000000          490973           648599  2018      2
# 2946            7200000           59774           295492  2011      9
# 2947            7200000           59774           295492  2011      9
# 2948            7200000           59774           295492  2011      9
# 2949            7200000           59774           295492  2011      9
#
#       total_gross         ROI
# 0       712452224  431.789227
# 1       933589720  549.170424
# 2      1128100837  705.063023
# 3       311819177  328.230713
# 4      1483884402  741.942201
# ...           ...         ...
# 2943      1139572    3.798573
# 2946       355266    4.934250
# 2947       355266    4.934250
# 2948       355266    4.934250
# 2949       355266    4.934250
#
# [2413 rows x 16 columns]

# %% [markdown]
# # Now that we have cleaned data, let's analyze it a bit so we can provide recommendations

# %% [markdown]
# # This is where we analyze genres

# %%
#To explore the trends by genre, first we must "explode" the genre_ids so that each film is listed once for each of 
#the genres it is in 
exploded = filtered_year.explode('genre_ids', ignore_index=False)

# %%
#let's reset our index for this genre data so that we can use iloc should we need to
exploded.reset_index()
# Out:
#       index  genre_ids  popularity                     title  vote_average  \
# 0         0    Fantasy      28.734  How to Train Your Dragon           7.7
# 1         0  Adventure      28.734  How to Train Your Dragon           7.7
# 2         0  Animation      28.734  How to Train Your Dragon           7.7
# 3         0     Family      28.734  How to Train Your Dragon           7.7
# 4         1  Adventure      28.515                Iron Man 2           6.8
# ...     ...        ...         ...                       ...           ...
# 5682   2948    Mystery       1.816                         3           6.0
# 5683   2948   Thriller       1.816                         3           6.0
# 5684   2949     Horror       1.816                         3           6.0
# 5685   2949    Mystery       1.816                         3           6.0
# 5686   2949   Thriller       1.816                         3           6.0
#
#       vote_count  runtime_minutes  averagerating  numvotes release_date_y  \
# 0           7610             98.0            8.1    611299   Mar 26, 2010
# 1           7610             98.0            8.1    611299   Mar 26, 2010
# 2           7610             98.0            8.1    611299   Mar 26, 2010
# 3           7610             98.0            8.1    611299   Mar 26, 2010
# 4          12368            124.0            7.0    657690    May 7, 2010
# ...          ...              ...            ...       ...            ...
# 5682           2            115.0            6.1       101   Sep 16, 2011
# 5683           2            115.0            6.1       101   Sep 16, 2011
# 5684           2             80.0            3.9       166   Sep 16, 2011
# 5685           2             80.0            3.9       166   Sep 16, 2011
# 5686           2             80.0            3.9       166   Sep 16, 2011
#
#       production_budget  domestic_gross  worldwide_gross  year  month  \
# 0             165000000       217581232        494870992  2010      3
# 1             165000000       217581232        494870992  2010      3
# 2             165000000       217581232        494870992  2010      3
# 3             165000000       217581232        494870992  2010      3
# 4             170000000       312433331        621156389  2010      5
# ...                 ...             ...              ...   ...    ...
# 5682            7200000           59774           295492  2011      9
# 5683            7200000           59774           295492  2011      9
# 5684            7200000           59774           295492  2011      9
# 5685            7200000           59774           295492  2011      9
# 5686            7200000           59774           295492  2011      9
#
#       total_gross         ROI
# 0       712452224  431.789227
# 1       712452224  431.789227
# 2       712452224  431.789227
# 3       712452224  431.789227
# 4       933589720  549.170424
# ...           ...         ...
# 5682       355266    4.934250
# 5683       355266    4.934250
# 5684       355266    4.934250
# 5685       355266    4.934250
# 5686       355266    4.934250
#
# [5687 rows x 17 columns]

# %%
#let's also assign this month column to "month" so we can call upon this series later
month = exploded['month']

# %%
#let's make a new dataframe where it is clear what the mean Return on Investment is for each genre
mean_genre_roi = month_genre_roi_title.groupby(['genre_ids']).mean().sort_values('ROI', ascending=False)
mean_genre_roi
# Out:
#                         year     month          ROI
# genre_ids
# Horror           2014.268882  6.362538  1262.137396
# Thriller         2014.001488  6.837798   710.039344
# Romance          2013.442804  6.719557   686.994579
# Mystery          2014.000000  7.080000   648.983450
# Fantasy          2014.319820  6.752252   612.421109
# Animation        2014.346457  7.307087   579.314389
# Comedy           2013.829305  6.818731   536.467224
# Drama            2014.149306  7.282986   508.626425
# Family           2013.976415  7.084906   483.200243
# Science Fiction  2014.270073  6.335766   459.918098
# Music            2014.479452  6.082192   408.017177
# Adventure        2014.284153  7.000000   402.116277
# Action           2014.112186  6.535783   386.072556
#                  2014.292308  5.923077   368.181968
# War              2014.705882  7.196078   366.276466
# History          2015.200000  8.031579   325.526085
# TV Movie         2012.000000  7.000000   314.125215
# Crime            2014.000000  7.268293   310.868734
# Documentary      2013.545455  6.896104   269.921513
# Western          2013.806452  7.612903   213.678350

# %%
#what are the genres with the top five largest means for Return on Investment? 
top_5_genres=list(mean_genre_roi.index[0:5])
top_5_genres
# Out:
# ['Horror', 'Thriller', 'Romance', 'Mystery', 'Fantasy']

# %%
#updating the dataframe to only include movies in the top 5 genres
month_genre_roi_title=month_genre_roi_title[month_genre_roi_title['genre_ids'].isin(top_5_genres)]

# %%
#for each genre, find mean ROI month by month
mean_roi_by_month = month_genre_roi_title.groupby(['month','genre_ids']).mean()

# %%
mean_roi_by_month
# Out:
#                         year          ROI
# month genre_ids
# 1     Fantasy    2015.466667  3031.587921
#       Horror     2014.756757  2326.510512
#       Mystery    2015.000000   863.517970
#       Romance    2014.470588  2778.134529
#       Thriller   2014.679245  1484.681271
# 2     Fantasy    2014.933333   494.423697
#       Horror     2014.478261   738.517758
#       Mystery    2013.923077  1171.765776
#       Romance    2013.750000   434.029557
#       Thriller   2013.634146   645.952342
# 3     Fantasy    2014.187500   505.491394
#       Horror     2014.952381   606.294990
#       Mystery    2014.529412   386.370561
#       Romance    2013.888889   387.997976
#       Thriller   2014.437500   376.222325
# 4     Fantasy    2014.000000   365.853312
#       Horror     2014.944444  1787.944932
#       Mystery    2013.666667   680.083678
#       Romance    2013.388889   356.180929
#       Thriller   2014.346667   985.029737
# 5     Fantasy    2013.421053   300.608688
#       Horror     2014.181818   689.021948
#       Mystery    2015.200000   119.745523
#       Romance    2012.952381   593.899116
#       Thriller   2014.225806   415.313737
# 6     Fantasy    2014.333333   715.672610
#       Horror     2014.642857   674.680060
#       Mystery    2015.222222   596.160235
#       Romance    2013.357143   665.262009
#       Thriller   2014.500000   500.853122
# 7     Fantasy    2013.800000   668.453873
#       Horror     2014.250000  4052.801697
#       Mystery    2014.818182   757.047379
#       Romance    2012.583333   757.803302
#       Thriller   2013.885714  2391.581187
# 8     Fantasy    2013.727273   412.320348
#       Horror     2013.296296   786.606903
#       Mystery    2014.052632  1078.706488
#       Romance    2012.925926   820.825188
#       Thriller   2013.265625   585.678126
# 9     Fantasy    2015.000000   281.028857
#       Horror     2014.395833   616.575462
#       Mystery    2013.214286   681.154778
#       Romance    2012.541667   378.634543
#       Thriller   2013.623529   532.198138
# 10    Fantasy    2013.571429   169.066131
#       Horror     2013.809524  1269.323476
#       Mystery    2014.322581   661.057454
#       Romance    2013.789474   456.125777
#       Thriller   2014.120879   598.487292
# 11    Fantasy    2015.448276   371.842246
#       Horror     2014.181818   140.118998
#       Mystery    2015.857143   493.132458
#       Romance    2013.333333   534.897978
#       Thriller   2014.297872   314.606493
# 12    Fantasy    2013.920000   484.656670
#       Horror     2012.652174    71.815650
#       Mystery    2012.454545   130.937498
#       Romance    2014.066667   623.234157
#       Thriller   2013.362069   197.341056

# %%
month_genre_roi_title
# Out:
#      genre_ids                                              title  year  \
# 0      Fantasy                           How to Train Your Dragon  2010
# 3      Fantasy  Percy Jackson & the Olympians: The Lightning T...  2010
# 7      Fantasy                                Alice in Wonderland  2010
# 9      Fantasy                                Alice in Wonderland  2010
# 15    Thriller                                    The Expendables  2010
# ...        ...                                                ...   ...
# 2948   Mystery                                                  3  2011
# 2948  Thriller                                                  3  2011
# 2949    Horror                                                  3  2011
# 2949   Mystery                                                  3  2011
# 2949  Thriller                                                  3  2011
#
#       month         ROI
# 0         3  431.789227
# 3         2  328.230713
# 7         3  679.841110
# 9         3  679.841110
# 15        8  452.849632
# ...     ...         ...
# 2948      9    4.934250
# 2948      9    4.934250
# 2949      9    4.934250
# 2949      9    4.934250
# 2949      9    4.934250
#
# [1696 rows x 5 columns]

# %% [markdown]
# # This is where we analyze directors

# %%
#make a dataframe with director names that had the tconst as unique identifier so that we can merge on tconst
title_principal_directors=title_principal[title_principal['category'] == 'director'] #created a new dataframe that filtered out only the directors from title_principal
nconst_to_name=dict(zip(list(name_basics['nconst']),list(name_basics['primary_name']))) #the dictionary where the keys are the nconsts and values are the primary names from name_basics
title_principal_directors['director_name']=title_principal_directors['nconst'].map(nconst_to_name) #creates a new column with the name of the director
    #third, merge title_master and title_principal_directors
master_directors=title_master.merge(title_principal_directors, on='tconst', how='inner' )
# Out:
# <ipython-input-43-31781bb5c6ed>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   title_principal_directors['director_name']=title_principal_directors['nconst'].map(nconst_to_name) #creates a new column with the name of the director

# %%
master_directors.head(3)
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
#
#    start_year  runtime_minutes              genres  averagerating  numvotes  \
# 0        2013            175.0  Action,Crime,Drama            7.0        77
# 1        2019            114.0     Biography,Drama            7.2        43
# 2        2018            122.0               Drama            6.9      4517
#
#    ordering     nconst  category  job characters        director_name
# 0         5  nm0712540  director  NaN        NaN  Harnam Singh Rawail
# 1         5  nm0002411  director  NaN        NaN            Mani Kaul
# 2         5  nm0000080  director  NaN        NaN         Orson Welles

# %%
filtered_year
# Out:
#                                     genre_ids  popularity  \
# 0     [Fantasy, Adventure, Animation, Family]      28.734
# 1        [Adventure, Action, Science Fiction]      28.515
# 2        [Action, Science Fiction, Adventure]      27.920
# 3                [Adventure, Fantasy, Family]      26.691
# 4                 [Animation, Family, Comedy]      24.445
# ...                                       ...         ...
# 2943           [Action, Adventure, Animation]       2.707
# 2946              [Horror, Mystery, Thriller]       1.816
# 2947              [Horror, Mystery, Thriller]       1.816
# 2948              [Horror, Mystery, Thriller]       1.816
# 2949              [Horror, Mystery, Thriller]       1.816
#
#                                                   title  vote_average  \
# 0                              How to Train Your Dragon           7.7
# 1                                            Iron Man 2           6.8
# 2                                             Inception           8.3
# 3     Percy Jackson & the Olympians: The Lightning T...           6.1
# 4                                           Toy Story 3           7.7
# ...                                                 ...           ...
# 2943                         Bilal: A New Breed of Hero           6.8
# 2946                                                  3           6.0
# 2947                                                  3           6.0
# 2948                                                  3           6.0
# 2949                                                  3           6.0
#
#       vote_count  runtime_minutes  averagerating  numvotes release_date_y  \
# 0           7610             98.0            8.1    611299   Mar 26, 2010
# 1          12368            124.0            7.0    657690    May 7, 2010
# 2          22186            148.0            8.8   1841066   Jul 16, 2010
# 3           4229            118.0            5.9    165108   Feb 12, 2010
# 4           8340            103.0            8.3    682218   Jun 18, 2010
# ...          ...              ...            ...       ...            ...
# 2943          54            105.0            8.0     16854    Feb 2, 2018
# 2946           2            119.0            6.7      4722   Sep 16, 2011
# 2947           2            145.0            7.2      3471   Sep 16, 2011
# 2948           2            115.0            6.1       101   Sep 16, 2011
# 2949           2             80.0            3.9       166   Sep 16, 2011
#
#       production_budget  domestic_gross  worldwide_gross  year  month  \
# 0             165000000       217581232        494870992  2010      3
# 1             170000000       312433331        621156389  2010      5
# 2             160000000       292576195        835524642  2010      7
# 3              95000000        88768303        223050874  2010      2
# 4             200000000       415004880       1068879522  2010      6
# ...                 ...             ...              ...   ...    ...
# 2943           30000000          490973           648599  2018      2
# 2946            7200000           59774           295492  2011      9
# 2947            7200000           59774           295492  2011      9
# 2948            7200000           59774           295492  2011      9
# 2949            7200000           59774           295492  2011      9
#
#       total_gross         ROI
# 0       712452224  431.789227
# 1       933589720  549.170424
# 2      1128100837  705.063023
# 3       311819177  328.230713
# 4      1483884402  741.942201
# ...           ...         ...
# 2943      1139572    3.798573
# 2946       355266    4.934250
# 2947       355266    4.934250
# 2948       355266    4.934250
# 2949       355266    4.934250
#
# [2413 rows x 16 columns]

# %%
director_filtered_df = filtered_year.merge(master_directors, how='inner')

# %%
director_filtered_df.head()
# Out:
#                                  genre_ids  popularity  \
# 0  [Fantasy, Adventure, Animation, Family]      28.734
# 1  [Fantasy, Adventure, Animation, Family]      28.734
# 2     [Adventure, Action, Science Fiction]      28.515
# 3     [Action, Science Fiction, Adventure]      27.920
# 4             [Adventure, Fantasy, Family]      26.691
#
#                                                title  vote_average  \
# 0                           How to Train Your Dragon           7.7
# 1                           How to Train Your Dragon           7.7
# 2                                         Iron Man 2           6.8
# 3                                          Inception           8.3
# 4  Percy Jackson & the Olympians: The Lightning T...           6.1
#
#    vote_count  runtime_minutes  averagerating  numvotes release_date_y  \
# 0        7610             98.0            8.1    611299   Mar 26, 2010
# 1        7610             98.0            8.1    611299   Mar 26, 2010
# 2       12368            124.0            7.0    657690    May 7, 2010
# 3       22186            148.0            8.8   1841066   Jul 16, 2010
# 4        4229            118.0            5.9    165108   Feb 12, 2010
#
#    production_budget  ...                                      primary_title  \
# 0          165000000  ...                           How to Train Your Dragon
# 1          165000000  ...                           How to Train Your Dragon
# 2          170000000  ...                                         Iron Man 2
# 3          160000000  ...                                          Inception
# 4           95000000  ...  Percy Jackson & the Olympians: The Lightning T...
#
#                                       original_title  start_year  \
# 0                           How to Train Your Dragon        2010
# 1                           How to Train Your Dragon        2010
# 2                                         Iron Man 2        2010
# 3                                          Inception        2010
# 4  Percy Jackson & the Olympians: The Lightning T...        2010
#
#                        genres  ordering     nconst  category  job characters  \
# 0  Action,Adventure,Animation         5  nm0213450  director  NaN        NaN
# 1  Action,Adventure,Animation         6  nm0761498  director  NaN        NaN
# 2     Action,Adventure,Sci-Fi         5  nm0269463  director  NaN        NaN
# 3     Action,Adventure,Sci-Fi         5  nm0634240  director  NaN        NaN
# 4    Adventure,Family,Fantasy         5  nm0001060  director  NaN        NaN
#
#        director_name
# 0       Dean DeBlois
# 1      Chris Sanders
# 2        Jon Favreau
# 3  Christopher Nolan
# 4     Chris Columbus
#
# [5 rows x 27 columns]

# %%
dropped_d_df = director_filtered_df.drop(['genre_ids', 'averagerating', 'release_date_y', 'tconst', 'primary_title', 'original_title',
                          'start_year', 'ordering', 'job', 'characters', 'domestic_gross', 'worldwide_gross' ], axis=1)

# %% [markdown]
# GROUPING THE DIRECTORS BASED ON THEIR POPULARITY

# %%
selected_directors = dropped_d_df.groupby(['ROI', 'popularity', 'production_budget'])

# %%
selected_directors.head(1)
# Out:
#       popularity                                              title  \
# 0         28.734                           How to Train Your Dragon
# 2         28.515                                         Iron Man 2
# 3         27.920                                          Inception
# 4         26.691  Percy Jackson & the Olympians: The Lightning T...
# 5         24.445                                        Toy Story 3
# ...          ...                                                ...
# 2622       5.599                                        Indivisible
# 2625       5.274                                         El Chicano
# 2626       4.486                                   Teefa in Trouble
# 2627       2.707                         Bilal: A New Breed of Hero
# 2629       1.816                                                  3
#
#       vote_average  vote_count  runtime_minutes  numvotes  production_budget  \
# 0              7.7        7610             98.0    611299          165000000
# 2              6.8       12368            124.0    657690          170000000
# 3              8.3       22186            148.0   1841066          160000000
# 4              6.1        4229            118.0    165108           95000000
# 5              7.7        8340            103.0    682218          200000000
# ...            ...         ...              ...       ...                ...
# 2622           5.4          13             78.0        10            2700000
# 2625           9.0           1            108.0       290            8000000
# 2626           7.6          11            155.0      2724            1500000
# 2627           6.8          54            105.0     16854           30000000
# 2629           6.0           2            119.0      4722            7200000
#
#       year  month  total_gross         ROI                      genres  \
# 0     2010      3    712452224  431.789227  Action,Adventure,Animation
# 2     2010      5    933589720  549.170424     Action,Adventure,Sci-Fi
# 3     2010      7   1128100837  705.063023     Action,Adventure,Sci-Fi
# 4     2010      2    311819177  328.230713    Adventure,Family,Fantasy
# 5     2010      6   1483884402  741.942201  Adventure,Animation,Comedy
# ...    ...    ...          ...         ...                         ...
# 2622  2018     10      7099722  262.952667                 Documentary
# 2625  2019      5      1400522   17.506525                       Drama
# 2626  2018      7        98806    6.587067         Action,Comedy,Crime
# 2627  2018      2      1139572    3.798573  Action,Adventure,Animation
# 2629  2011      9       355266    4.934250        Comedy,Drama,Romance
#
#          nconst  category       director_name
# 0     nm0213450  director        Dean DeBlois
# 2     nm0269463  director         Jon Favreau
# 3     nm0634240  director   Christopher Nolan
# 4     nm0001060  director      Chris Columbus
# 5     nm0881279  director         Lee Unkrich
# ...         ...       ...                 ...
# 2622  nm7684122  director       Hilary Linder
# 2625  nm0004554  director  Ben Hernandez Bray
# 2626  nm6773153  director         Ahsan Rahim
# 2627  nm6735778  director    Khurram H. Alavi
# 2629  nm0878756  director          Tom Tykwer
#
# [1689 rows x 15 columns]

# %% [markdown]
# giving the next upcoming directors that has the most Return an opprtunity to showcase their talent and providing a platform for growth

# %%
director_metric = director_filtered_df[['director_name', 'ROI', 'production_budget']]
# grouped_director_cost = director_metric.groupby('production_budget', as_index=False).mean()
roi_directors = director_metric.sort_values(by='ROI', ascending=False)
roi_directors.head(10)
# Out:
#               director_name           ROI  production_budget
# 1866           Travis Cluff  64420.884000             100000
# 1867           Chris Lofing  64420.884000             100000
# 916      William Brent Bell  15502.243500            1000000
# 357               James Wan  10258.669067            1500000
# 1890        Levan Gabriadze   9715.384300            1000000
# 170            Tod Williams   8742.164633            3000000
# 299            Jordan Peele   8628.172320            5000000
# 298            Jordan Peele   8628.172320            5000000
# 1052      Deborah Kampmeier   8342.127820            5000000
# 1062  Lawrence Côté-Collins   8342.127820            5000000

# %% [markdown]
# The ten best directors in regards to their box ofice potential.

# %%
director_metrics = director_filtered_df[['director_name', 'total_gross', 'production_budget']]
# grouped_directors_cost = director_metrics.groupby('production_budget', as_index=False)
costly_directors = director_metrics.sort_values(by='total_gross', ascending=False)
ten_cost_directors = costly_directors.head(10)

# %%
sns.set(font_scale = 5)
sns.set(style="whitegrid", color_codes=True)
pal = sns.color_palette("Greens_d", len(ten_cost_directors))
fig, ax = plt.subplots()
fig.set_size_inches(30,15)
ax = sns.barplot(x="director_name", y="total_gross", ci=None, palette=np.array(pal[::-1]),data=ten_cost_directors)
plt.xlabel('Director names', fontsize=25, weight = 'bold')
plt.ylabel('Total Revenue (In Millions Of U.S. Dollars)', fontsize=25, weight = 'bold')
plt.yticks(ax.get_yticks(), ax.get_yticks()/1000000)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.show()

# %% [markdown]
# Top ten directors whose work had an higher vote to be nominated

# %%
director_award_metric = director_filtered_df[['director_name', 'numvotes', 'vote_average']]
award_directors = director_award_metric.sort_values(by='numvotes', ascending=False)
award_directors.head(10)
# Out:
#           director_name  numvotes  vote_average
# 3     Christopher Nolan   1841066           8.3
# 755   Christopher Nolan   1387769           7.7
# 1418  Christopher Nolan   1299334           8.2
# 761   Quentin Tarantino   1211405           8.0
# 751         Joss Whedon   1183655           7.6
# 18      Martin Scorsese   1005960           8.1
# 1405         James Gunn    948394           7.9
# 2037         Tim Miller    820847           7.6
# 800           Gary Ross    795227           7.1
# 1702      George Miller    780910           7.4
