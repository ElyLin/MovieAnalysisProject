# %%
import pandas as pd

# %%
df = pd.read_csv('dsc-phase-1-project-v2-3/zippedData/bom.movie_gross.csv.gz')

# %%
df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
df['foreign_gross'].value_counts()
# Out:
# 1200000     23
# 1100000     14
# 4200000     12
# 1900000     12
# 1300000     11
#             ..
# 27100000     1
# 55100000     1
# 1,131.6      1
# 1,163.0      1
# 28700000     1
# Name: foreign_gross, Length: 1204, dtype: int64

# %%
df.loc[df['foreign_gross'] == '1,131.6']['foreign_gross'][1872].replace(',','')
# Out:
# '1131.6'

# %%
df['foreign_gross'].str.replace(',', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-172e7132d4ba> in <module>
# ----> 1 df['foreign_gross'].str.replace(',', '').astype(int)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %%
df['foreign_gross'].fillna(0)
# Out:
# 0       652000000
# 1       691300000
# 2       664300000
# 3       535700000
# 4       513900000
#           ...
# 3382            0
# 3383            0
# 3384            0
# 3385            0
# 3386            0
# Name: foreign_gross, Length: 3387, dtype: object

# %%
df_floats = df[df['foreign_gross'].str.replace(',', '').astype(float)]
df_floats
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-193e13b76b63> in <module>
# ----> 1 df_floats = df[df['foreign_gross'].str.replace(',', '').astype(float)]
#       2 df_floats
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
# ...

# %%
top_domestic_gross = df.sort_values(by='domestic_gross', ascending=False)

# %%
top_30_domestic = top_domestic_gross.head(30)

# %%
top_foreign_gross = df.sort_values(by='foreign_gross', ascending=False)

# %%
df_floats
# Out:
# 0       652000000.0
# 1       691300000.0
# 2       664300000.0
# 3       535700000.0
# 4       513900000.0
#            ...
# 3382            NaN
# 3383            NaN
# 3384            NaN
# 3385            NaN
# 3386            NaN
# Name: foreign_gross, Length: 3387, dtype: float64

# %%
df.foreign_gross.astype(float, errors='ignore')
# Out:
# 0       652000000
# 1       691300000
# 2       664300000
# 3       535700000
# 4       513900000
#           ...
# 3382          NaN
# 3383          NaN
# 3384          NaN
# 3385          NaN
# 3386          NaN
# Name: foreign_gross, Length: 3387, dtype: object

# %%
df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
df.sort_values(by='foreign_gross', ascending=False)
# Out:
#                             title      studio  domestic_gross foreign_gross  \
# 1805              Life's a Breeze       Magn.          3500.0         99700
# 1331                     The East        FoxS       2300000.0         99700
# 302                    White Lion       Scre.             NaN         99600
# 2906             A United Kingdom        FoxS       3900000.0       9900000
# 510                      Le Havre        Jan.        612000.0       9900000
# ...                           ...         ...             ...           ...
# 3382                    The Quake       Magn.          6200.0           NaN
# 3383  Edward II (2018 re-release)          FM          4800.0           NaN
# 3384                     El Pacto        Sony          2500.0           NaN
# 3385                     The Swan  Synergetic          2400.0           NaN
# 3386            An Actor Prepares       Grav.          1700.0           NaN
#
#       year
# 1805  2014
# 1331  2013
# 302   2010
# ...

# %%
pd.
# Out:
#   File "<ipython-input-84-bc888235687a>", line 1
#     pd.
#        ^
# SyntaxError: invalid syntax

# %%
df['total_gross'] = df_floats + df['domestic_gross']

# %%
df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
# ...

# %%
top_20_total = df.sort_values('total_gross', ascending=False).head(20)

# %%
top_20_total
# Out:
#                                             title studio  domestic_gross  \
# 727                         Marvel's The Avengers     BV     623400000.0
# 1875                      Avengers: Age of Ultron     BV     459000000.0
# 3080                                Black Panther     BV     700100000.0
# 328   Harry Potter and the Deathly Hallows Part 2     WB     381000000.0
# 2758                     Star Wars: The Last Jedi     BV     620200000.0
# 3081               Jurassic World: Fallen Kingdom   Uni.     417700000.0
# 1127                                       Frozen     BV     400700000.0
# 2759                  Beauty and the Beast (2017)     BV     504000000.0
# 3082                                Incredibles 2     BV     608600000.0
# 1128                                   Iron Man 3     BV     409000000.0
# 1876                                      Minions   Uni.     336000000.0
# 2322                   Captain America: Civil War     BV     408100000.0
# ...

# %%
top_20_total = top_20_total.drop('total gross', axis=1)

# %%
top_20_total
# Out:
#                                             title studio  domestic_gross  \
# 727                         Marvel's The Avengers     BV     623400000.0
# 1875                      Avengers: Age of Ultron     BV     459000000.0
# 3080                                Black Panther     BV     700100000.0
# 328   Harry Potter and the Deathly Hallows Part 2     WB     381000000.0
# 2758                     Star Wars: The Last Jedi     BV     620200000.0
# 3081               Jurassic World: Fallen Kingdom   Uni.     417700000.0
# 1127                                       Frozen     BV     400700000.0
# 2759                  Beauty and the Beast (2017)     BV     504000000.0
# 3082                                Incredibles 2     BV     608600000.0
# 1128                                   Iron Man 3     BV     409000000.0
# 1876                                      Minions   Uni.     336000000.0
# 2322                   Captain America: Civil War     BV     408100000.0
# ...

# %%
studio_num_movies = df.groupby('studio')['title'].count().sort_values(ascending=False)
studio_num_movies
# Out:
# studio
# IFC       166
# Uni.      147
# WB        140
# Fox       136
# Magn.     136
#          ...
# ITL         1
# IVP         1
# IW          1
# Indic.      1
# KKM         1
# Name: title, Length: 257, dtype: int64

# %%
studio_total_gross = df.groupby('studio')['total_gross'].sum().sort_values(ascending=False)
studio_total_gross
# Out:
# studio
# BV            4.419038e+10
# Fox           3.098037e+10
# WB            3.079150e+10
# Uni.          2.974681e+10
# Sony          2.240472e+10
#                   ...
# Orion         0.000000e+00
# Cdgm.         0.000000e+00
# CineGalaxy    0.000000e+00
# Cleopatra     0.000000e+00
# PI            0.000000e+00
# Name: total_gross, Length: 257, dtype: float64

# %%
average_gross_per_movie = studio_total_gross/studio_num_movies
average_gross_per_movie
# Out:
# studio
# 3D       1.600000e+07
# A23      0.000000e+00
# A24      1.018202e+07
# ADC      0.000000e+00
# AF       7.758333e+05
#              ...
# XL       0.000000e+00
# YFG      0.000000e+00
# Yash     2.108818e+07
# Zee      1.671000e+06
# Zeit.    1.376825e+06
# Length: 257, dtype: float64

# %%
average_per_movie_top = average_gross_per_movie.sort_values(ascending=False).head(20)
average_per_movie_top
# Out:
# studio
# HC          8.703000e+08
# P/DW        5.076500e+08
# BV          4.168904e+08
# GrtIndia    2.542000e+08
# WB (NL)     2.292022e+08
# Fox         2.277968e+08
# WB          2.199393e+08
# Sony        2.036792e+08
# Uni.        2.023592e+08
# Par.        1.925168e+08
# Sum.        1.523314e+08
# WAMCR       1.350226e+08
# LG/S        1.297299e+08
# MGM         9.286667e+07
# SGem        8.971891e+07
# LGF         8.220845e+07
# TriS        7.448065e+07
# Studio 8    6.205000e+07
# STX         6.142500e+07
# W/Dim.      5.409519e+07
# dtype: float64

# %%
ndf = pd.DataFrame(data=studio_num_movies)

# %%
ndf['number_of_movies'] = studio_num_movies
ndf
# Out:
#         title  number_of_movies
# studio
# IFC       166               166
# Uni.      147               147
# WB        140               140
# Fox       136               136
# Magn.     136               136
# ...       ...               ...
# ITL         1                 1
# IVP         1                 1
# IW          1                 1
# Indic.      1                 1
# KKM         1                 1
#
# [257 rows x 2 columns]

# %%
ndf['gross_per_studio'] = studio_total_gross
ndf
# Out:
#         title  number_of_movies   total_gross  gross_per_studio
# studio
# IFC       166               166  4.698994e+08      4.698994e+08
# Uni.      147               147  2.974681e+10      2.974681e+10
# WB        140               140  3.079150e+10      3.079150e+10
# Fox       136               136  3.098037e+10      3.098037e+10
# Magn.     136               136  5.297370e+08      5.297370e+08
# ...       ...               ...           ...               ...
# ITL         1                 1  5.290000e+04      5.290000e+04
# IVP         1                 1  1.121000e+05      1.121000e+05
# IW          1                 1  3.800000e+06      3.800000e+06
# Indic.      1                 1  0.000000e+00      0.000000e+00
# KKM         1                 1  3.055000e+06      3.055000e+06
#
# [257 rows x 4 columns]

# %%
ndf = ndf.drop('total_gross', axis=1)
ndf
# Out:
#         title  number_of_movies  gross_per_studio
# studio
# IFC       166               166      4.698994e+08
# Uni.      147               147      2.974681e+10
# WB        140               140      3.079150e+10
# Fox       136               136      3.098037e+10
# Magn.     136               136      5.297370e+08
# ...       ...               ...               ...
# ITL         1                 1      5.290000e+04
# IVP         1                 1      1.121000e+05
# IW          1                 1      3.800000e+06
# Indic.      1                 1      0.000000e+00
# KKM         1                 1      3.055000e+06
#
# [257 rows x 3 columns]

# %%
ndf['average_gross_per_movie'] = average_gross_per_movie
ndf
# Out:
#         title  number_of_movies  gross_per_studio  average_gross_per_movie
# studio
# IFC       166               166      4.698994e+08             2.830719e+06
# Uni.      147               147      2.974681e+10             2.023592e+08
# WB        140               140      3.079150e+10             2.199393e+08
# Fox       136               136      3.098037e+10             2.277968e+08
# Magn.     136               136      5.297370e+08             3.895125e+06
# ...       ...               ...               ...                      ...
# ITL         1                 1      5.290000e+04             5.290000e+04
# IVP         1                 1      1.121000e+05             1.121000e+05
# IW          1                 1      3.800000e+06             3.800000e+06
# Indic.      1                 1      0.000000e+00             0.000000e+00
# KKM         1                 1      3.055000e+06             3.055000e+06
#
# [257 rows x 4 columns]

# %%
ndf.sort_values(by='average_gross_per_movie', ascending=False)
# Out:
#             title  number_of_movies  gross_per_studio  average_gross_per_movie
# studio
# HC              1                 1      8.703000e+08             8.703000e+08
# P/DW           10                10      5.076500e+09             5.076500e+08
# BV            106               106      4.419038e+10             4.168904e+08
# GrtIndia        1                 1      2.542000e+08             2.542000e+08
# WB (NL)        45                45      1.031410e+10             2.292022e+08
# ...           ...               ...               ...                      ...
# SMod            1                 1      0.000000e+00             0.000000e+00
# Synergetic      1                 1      0.000000e+00             0.000000e+00
# Saban           1                 1      0.000000e+00             0.000000e+00
# Swen            1                 1      0.000000e+00             0.000000e+00
# YFG             1                 1      0.000000e+00             0.000000e+00
#
# ...
